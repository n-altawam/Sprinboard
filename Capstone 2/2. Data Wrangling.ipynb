# %% [markdown]
# ## Data Collection

# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option(('display.max_columns'), (None))

# %%
#listings data obtained from http://insideairbnb.com/get-the-data
listings = "./data/source/listings.csv" #Listings data
listings_detailed = "./data/source/listings_detail.csv.gz" #Summary information and metrics for listings in New York City

df = pd.read_csv(listings, low_memory=False)
df_detailed = pd.read_csv(listings_detailed, low_memory=False)
df.shape, df_detailed.shape
# Out:
# ((41533, 18), (41533, 75))

# %%
# Inspecting the data
df.head()
# Out:
#      id                                      name  host_id  host_name  \
# 0  5136  Spacious Brooklyn Duplex, Patio + Garden     7378    Rebecca
# 1  5203        Cozy Clean Guest Room - Family Apt     7490  MaryEllen
# 2  5121                           BlissArtsSpace!     7356      Garon
# 3  5178          Large Furnished Room Near B'way　     8967   Shunichi
# 4  2595                     Skylit Midtown Castle     2845   Jennifer
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0            Brooklyn         Sunset Park  40.66265  -73.99454
# 1           Manhattan     Upper West Side  40.80380  -73.96751
# 2            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 3           Manhattan             Midtown  40.76457  -73.98317
# 4           Manhattan             Midtown  40.75356  -73.98559
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    275              21                  3  2022-08-10
# ...

# %%
df_detailed.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20221204162430   2022-12-05
# 1  5203  https://www.airbnb.com/rooms/5203  20221204162430   2022-12-05
# 2  5136  https://www.airbnb.com/rooms/5136  20221204162430   2022-12-04
# 3  5121  https://www.airbnb.com/rooms/5121  20221204162430   2022-12-05
# 4  6848  https://www.airbnb.com/rooms/6848  20221204162430   2022-12-05
#
#             source                                      name  \
# 0      city scrape                     Skylit Midtown Castle
# 1  previous scrape        Cozy Clean Guest Room - Family Apt
# 2      city scrape  Spacious Brooklyn Duplex, Patio + Garden
# 3      city scrape                           BlissArtsSpace!
# 4      city scrape          Only 2 stops to Manhattan studio
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Our best guests are seeking a safe, clean, spa...
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Ill start by inspecting the nulls.

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# license                           41532
# reviews_per_month                  9393
# last_review                        9393
# name                                 13
# host_name                             5
# minimum_nights                        0
# number_of_reviews_ltm                 0
# availability_365                      0
# calculated_host_listings_count        0
# number_of_reviews                     0
# id                                    0
# room_type                             0
# longitude                             0
# latitude                              0
# neighbourhood                         0
# neighbourhood_group                   0
# host_id                               0
# price                                 0
# dtype: int64

# %% [markdown]
# The licence information is irrelevant to the project and will be dropped.
#
# There are 13 entries under the `name` field that are missing, as well as 9393 entries related to reviews. I will insepct these to see whats missing.

# %%
df = df.drop('license', axis=1)

# %%
df[df.name.isna()]
# Out:
#              id name    host_id host_name neighbourhood_group  \
# 1827    2232600  NaN   11395220      Anna           Manhattan
# 2831    4209595  NaN   20700823     Jesse           Manhattan
# 2982    4370230  NaN   22686810   Michaël           Manhattan
# 3099    4581788  NaN   21600904     Lucie            Brooklyn
# 3296    4774658  NaN   24625694      Josh           Manhattan
# 4395    6782407  NaN   31147528  Huei-Yin            Brooklyn
# 5916    9325951  NaN   33377685  Jonathan           Manhattan
# 6343    9787590  NaN   50448556    Miguel           Manhattan
# 6675   10116081  NaN   51913270    Andrew           Manhattan
# 6711   10052289  NaN   49522403   Vanessa            Brooklyn
# 7816   12988898  NaN   71552588    Andrea               Bronx
# 7839   12797684  NaN   69715276       Yan           Manhattan
# 11742  21044649  NaN  151547086     Tanya               Bronx
#
#             neighbourhood  latitude  longitude        room_type  price  \
# ...

# %% [markdown]
# There doesn't appear to be any visual correlation between these listings in terms of location or host. Most of them have no reviews, and without a description highlighting amenities, we wont be able to include them in the comparisons. For now, I will name them 'Unnamed Listing' and we'll decide if any value can be extracted during the EDA step.

# %%
df.name.fillna('Unnamed Listing', inplace=True)

# %%
df.price.describe()
# Out:
# count    41533.000000
# mean       221.978282
# std        919.502236
# min          0.000000
# 25%         80.000000
# 50%        131.000000
# 75%        220.000000
# max      98159.000000
# Name: price, dtype: float64

# %%
# The minimum value indicates there are listings for $0. 
df[df.price == 0]
# Out:
#              id                                  name    host_id  \
# 20487  40560656  The Hoxton, Williamsburg - Cosy Room  273324213
# 21001  41792753                 Mint House At 70 Pine  197053492
# 21010  41740615            The James New York - NoMad  268417148
# 21011  41740622       Gardens Suites Hotel by Affinia  269311462
# 21148  42065543                  Broadway Plaza Hotel  307634016
# 21152  42065545                       Carvi Hotel NYC  310429455
# 21154  42065547                          Hotel Five44  308721299
# 21155  42065555                          Pod Hotel BK  309714886
# 21162  42065562                         Artezen Hotel  307633956
# 21167  42065563                     Opera House Hotel  309772430
# 21168  42065564                   The Wall Street Inn  314151200
# 21224  42228997                  Sister City New York  314197504
# 21278  42279171                        Leon Hotel LES  265458818
# ...

# %% [markdown]
# It looks like there are 30 listings with a price of $0. This may be true or it may be an error, but there is no efficient way to check. Additionally, these entries are all listed as Hotel room for the `room_type`. Since the start-up will not be including these in their listing, we may drop them all together. For now, I will drop these entries since they wont help with the price.

# %%
df = df[df.price != 0]
df.price.describe()
# Out:
# count    41503.000000
# mean       222.138737
# std        919.815135
# min         10.000000
# 25%         80.000000
# 50%        131.000000
# 75%        220.000000
# max      98159.000000
# Name: price, dtype: float64

# %% [markdown]
# I will replace the null values in the `reviews_per_month` column with 0. As for the `last_review` column, it may be of help later in measuring the activity of listings but it will be dropped for now.

# %%
df.reviews_per_month.fillna(0)
df = df.drop('last_review', axis=1)
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm'],
#       dtype='object')

# %% [markdown]
# `id` and `name` are the only identifiers needed. The `host_name` and `host_id` will be dropped.

# %%
df_final = df.drop(['host_name', 'host_id'], axis=1)
print(df_final.columns)
# Out:
# Index(['id', 'name', 'host_id', 'neighbourhood_group', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm'],
#       dtype='object')

# %%
df_detailed.columns()

# %% [markdown]
# The features I plan to investigate effect on price are: location, property type, and number of rooms.
#
# For location: I'll be using the `neighbourhood` and `neighbourhood_group` as classifiers. The geocode location can be added later for a more in depth analysis or new feature engineering.
#
# The `room_type` entry comprises of the following unique values: 'Entire home/apt', 'Private room', 'Hotel room', 'Shared room'. Hotel room entries will be dropped in a future step.
#
# `accommodates` and `bedrooms` are integers relating to number of guests.
# `bathrooms_text` contains string data about the number of baths.
# These will also be added in the EDA step.
#
# `amenities` is a json object of self-reported available amenities. This may be used in a future step.
#
# To investigate local market conditions: I will investigate the hosts mentioned `availability_365`. This may be used to calculate occupancy rate in a future step.
#
# Past rental data in this case will include: the `number_of_reviews` and `number_of_reviews_ltm` which is specific to the past 12 months.
#
# The remaining features will be left in during the EDA step to check for other correlations.

# %%
listings_final = df_final.merge(df_detailed[['accommodates', 'bedrooms', 'bathrooms_text', 'amenities', 'id','beds']], on='id', how='left')

# %%
df_final.shape, listings_final.shape
# Out:
# ((41503, 15), (41503, 20))

# %%
listings_final.to_csv('./data/listings_wrangled', index=False)
